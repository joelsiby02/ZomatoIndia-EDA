# %%
#importing libaries
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
# %matplotlib inline

# %%
# Loading dataSet
df0 = pd.read_csv('zomato.csv', encoding='latin-1')

# %%
# first 5 and last 5
for i in [df0.head(), df0.tail()]:
    display(i)
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
# info about your DataSet
df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %% [markdown]
# ### Insights:  20 columns, float - 3, int - 5, object -13

# %%
# Describe dataset 
df0.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %% [markdown]
# '''
# ##### 1/ Missing values
# ##### 2/Explore numerical varibales
# ##### 3/Explore categorical variables
# ##### 4/ Relation between Features
# '''

# %%
# Missing values
df0.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %% [markdown]
# #### Insights: 'Cusine' col has 9 null values

# %%
# trying new things xD
import missingno as msno
msno.matrix(df0)
# Out:
# <AxesSubplot:>

# %%
#Loading an Excel file
df_country = pd.read_excel('Country-Code.xlsx')

# %%
for i in [df_country.head(), df_country.tail()]:
    display(i)
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia
#     Country Code         Country
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
df_country.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Code  15 non-null     int64
#  1   Country       15 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 368.0+ bytes

# %%
# Merging 2 datasets df0 & df_country
df = pd.merge(df0, df_country, on='Country Code', how='left')

# %%
for i in [df.head(), df.tail()]:
    display(i)
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %% [markdown]
# ### Merged dataset is 'df'

# %%
country_value = df.Country.value_counts()
print(country_value)
# Out:
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# UAE                 60
# South Africa        60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Singapore           20
# Qatar               20
# Sri Lanka           20
# Canada               4
# Name: Country, dtype: int64

# %%
df.Country.value_counts().values
# Out:
# array([8652,  434,   80,   60,   60,   60,   40,   34,   24,   22,   21,
#          20,   20,   20,    4], dtype=int64)

# %%
# top 3 country that uses zomato in a PiePlot
top_3_countries = country_value.head(3)
labels = top_3_countries.index
sizes = top_3_countries.values

plt.figure(figsize=(4, 3))  # Adjust the figure size as per your preference

plt.pie(sizes, labels=labels, autopct='%1.1f%%')
plt.axis('equal')
plt.title('Top 3 Countries')
plt.show()

# %% [markdown]
# #### Top 3 countries with 'Max' records in the Dataset
# #### 1/ India - 95 %
# #### 2/ UK - 1 %
# #### 3/ 4.7 %

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
# Grouped 3 col's
rate_color_text = df.groupby(['Aggregate rating', 'Rating color', 'Rating text']).size().reset_index()
# Renaming a col '0' to 'Rating count'
rate_color_text = result.rename(columns={0: 'Rating count'})
rate_color_text
# Out:
#     Aggregate rating Rating color Rating text  Rating count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# ...

# %%
for rating, text in zip(rate_color_text['Aggregate rating'], rate_color_text['Rating text']):
    print(f"{rating:.1f} - {rating:.1f} [{text}]: {text}")
# Out:
# 0.0 - 0.0 [Not rated]: Not rated
# 1.8 - 1.8 [Poor]: Poor
# 1.9 - 1.9 [Poor]: Poor
# 2.0 - 2.0 [Poor]: Poor
# 2.1 - 2.1 [Poor]: Poor
# 2.2 - 2.2 [Poor]: Poor
# 2.3 - 2.3 [Poor]: Poor
# 2.4 - 2.4 [Poor]: Poor
# 2.5 - 2.5 [Average]: Average
# 2.6 - 2.6 [Average]: Average
# 2.7 - 2.7 [Average]: Average
# 2.8 - 2.8 [Average]: Average
# 2.9 - 2.9 [Average]: Average
# 3.0 - 3.0 [Average]: Average
# 3.1 - 3.1 [Average]: Average
# 3.2 - 3.2 [Average]: Average
# 3.3 - 3.3 [Average]: Average
# 3.4 - 3.4 [Average]: Average
# 3.5 - 3.5 [Good]: Good
# 3.6 - 3.6 [Good]: Good
# 3.7 - 3.7 [Good]: Good
# 3.8 - 3.8 [Good]: Good
# 3.9 - 3.9 [Good]: Good
# 4.0 - 4.0 [Very Good]: Very Good
# 4.1 - 4.1 [Very Good]: Very Good
# 4.2 - 4.2 [Very Good]: Very Good
# 4.3 - 4.3 [Very Good]: Very Good
# 4.4 - 4.4 [Very Good]: Very Good
# 4.5 - 4.5 [Excellent]: Excellent
# 4.6 - 4.6 [Excellent]: Excellent
# 4.7 - 4.7 [Excellent]: Excellent
# 4.8 - 4.8 [Excellent]: Excellent
# 4.9 - 4.9 [Excellent]: Excellent

# %% [markdown]
# #### Conlusion
# #####  0 - 2148 not rated
# #####  4.9 to 4.5 [Excellent]
# #####  4.4 to 4.0 [Very Good]
# #####  3.5 to 3.9 [Good]
# #####  2.5 to 3.4 [Avg]
# #####  1.8 to 2.4 [Poor]

# %%
matplotlib.rcParams['figure.figsize'] = (12,6)
sns.barplot(x = 'Aggregate rating', y = 'Rating count',hue = 'Rating color', data = rate_color_text,palette = ['black', 'red', 'orange', 'yellow', 'green', 'green'])
# Out:
# <AxesSubplot:xlabel='Aggregate rating', ylabel='Rating count'>

# %%
sns.barplot(x = "Aggregate rating", y = "Rating color", hue = 'Rating color', data = rate_color_text, palette = ['white', 'red', 'orange', 'yellow', 'green', 'green'] )
# Out:
# <AxesSubplot:xlabel='Aggregate rating', ylabel='Rating color'>

# %% [markdown]
# #### Observations
#    1. Not rating count [blue] is so High
#    2. Max number of rating is from 2.5 to 3.4

# %% [markdown]
# ### Q. Country's that has given 0 ratings

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
country_rating = df[df['Rating color'] == 'White'].groupby('Country').size().reset_index()
country_rating
# Out:
#           Country     0
# 0          Brazil     5
# 1           India  2139
# 2  United Kingdom     1
# 3   United States     3

# %% [markdown]
# ### Observations:
#    1. Brazil has 5  ->  0 ratings
#    2. India has 2139 ->  0 ratings

# %% [markdown]
# ### Q. Which currency is used in which country

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
currency_country = df.groupby(['Currency', 'Country'])

# %%
currency_country[['Currency', 'Country']].head()
# Out:
#               Currency      Country
# 0     Botswana Pula(P)  Phillipines
# 1     Botswana Pula(P)  Phillipines
# 2     Botswana Pula(P)  Phillipines
# 3     Botswana Pula(P)  Phillipines
# 4     Botswana Pula(P)  Phillipines
# ...                ...          ...
# 9517  Turkish Lira(TL)       Turkey
# 9518  Turkish Lira(TL)       Turkey
# 9519  Turkish Lira(TL)       Turkey
# 9520  Turkish Lira(TL)       Turkey
# 9521  Turkish Lira(TL)       Turkey
#
# [74 rows x 2 columns]

# %%
flag = False
for name, group in currency_country:
    print(f"The currency used in {name[1]} is {name[0]}")
# Out:
# The currency used in Phillipines is Botswana Pula(P)
# The currency used in Brazil is Brazilian Real(R$)
# The currency used in Australia is Dollar($)
# The currency used in Canada is Dollar($)
# The currency used in Singapore is Dollar($)
# The currency used in United States is Dollar($)
# The currency used in UAE is Emirati Diram(AED)
# The currency used in India is Indian Rupees(Rs.)
# The currency used in Indonesia is Indonesian Rupiah(IDR)
# The currency used in New Zealand is NewZealand($)
# The currency used in United Kingdom is Pounds(£)
# The currency used in Qatar is Qatari Rial(QR)
# The currency used in South Africa is Rand(R)
# The currency used in Sri Lanka is Sri Lankan Rupee(LKR)
# The currency used in Turkey is Turkish Lira(TL)

# %% [markdown]
# # Which country's have online delivery opt?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df[df['Has Online delivery'] == "Yes"].Country.value_counts()
# Out:
# India    2423
# UAE        28
# Name: Country, dtype: int64

# %%
df[['Has Online delivery' , 'Country']].groupby(['Has Online delivery', 'Country']).size().reset_index()
# Out:
#    Has Online delivery         Country     0
# 0                   No       Australia    24
# 1                   No          Brazil    60
# 2                   No          Canada     4
# 3                   No           India  6229
# 4                   No       Indonesia    21
# 5                   No     New Zealand    40
# 6                   No     Phillipines    22
# 7                   No           Qatar    20
# 8                   No       Singapore    20
# 9                   No    South Africa    60
# 10                  No       Sri Lanka    20
# 11                  No          Turkey    34
# 12                  No             UAE    32
# 13                  No  United Kingdom    80
# 14                  No   United States   434
# 15                 Yes           India  2423
# 16                 Yes             UAE    28

# %% [markdown]
# #### Observations:
#  - Online delivery is available in UAE & INDIA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df['City'].value_counts().index

# %%
city_counts = df['City'].value_counts().head(5)

# Plotting a pie chart for the top 5 cities
plt.figure(figsize=(10, 6))
plt.pie(city_counts, labels=city_counts.index, autopct='%1.1f%%')
plt.title('Top 5 Cities Distribution')
plt.axis('equal')
plt.show()

# %% [markdown]
# ### Observation
#  - Max number of Transactions from 'New Delhi'
